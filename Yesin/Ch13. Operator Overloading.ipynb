# %% [markdown]
# # Chapter13. 연산자 오버로딩: 제대로하기
#
# 연산자 오버로딩은 사용자 정의 객체가 `+` 와 `|` 같은 연산자 ,`-`와 `~` 같은 단항 연산자를 사용할 수 있게 해준다. 파이썬에서는 여기에서 더 나아가 함수 호출`()`, 속성 접근 `.`, 항목 접근/슬라이싱`[]`도 연산자로 구현되어 있지만, 이 장에서는 단항 연산자와 중위 연산자만 다룬다.
#
# ## 13.1 연산자 오버로딩 기본 지식
# 연산자 오버로딩을 혐오하는 사람도 많다. 이 언어 기능은 남용되거나, 프로그래머를 혼란스럽게 만들거나, 버그를 만들거나, 예상치 못한 성능상의 병목이 될 수도 있다. 파이썬은 다음과 같은 제한을 두어 융통성, 사용성, 안전성을 적절히 유지한다.
# - 내장 자료형에 대한 연산자는 오버로딩할 수 없다.
# - 새로운 연산자를 생성할 수 없으며, 기존 연산자를 오버로딩만 할 수 있다.
# - is, and, or, not 연산자는 오버로딩할 수 없다. (그러나 &, |, ~ 같은 비트 연산자는 가능하다.)

# %%
# Vector v6
def __abs__(self):
    return math.sqrt(sum(x * x for x in self))

def __neg__(self):
    """단항 산술 부정(`-`). x가 -2면, -x는 2다."""
    return Vector2d(-x for x in self)

def __pos__(self):
    """단항 산술 덧셈(`+`). 일반적으로 x와 -x는 동일하지만, 그렇지 않은 경우도 있다. 이 절 끝에 나오는 'x와 +x가 동일하지 않은 경우' 글상자에서 자세히 설명한다."""
    return Vector2d

# %%
# x와 +x가 동일하지 않은 경우
import decimal

ctx = decimal.getcontext()
ctx.prec = 40
one_third = decimal.Decimal('1') / decimal.Decimal('3')
print(one_third)
print(one_third == +one_third)

ctx.prec = 28
print(one_third == +one_third)
print(+one_third)
print(one_third)
# Out:
# 0.3333333333333333333333333333333333333333
# True
# False
# 0.3333333333333333333333333333
# 0.3333333333333333333333333333333333333333

# %%
from collections import Counter


ct = Counter('abracadabra')
ct
# Out:
# Counter({'a': 5, 'b': 2, 'r': 2, 'c': 1, 'd': 1})

# %%
ct['r'] = -3
ct['d'] = 0
ct
# Out:
# Counter({'a': 5, 'b': 2, 'r': -3, 'c': 1, 'd': 0})

# %%
+ct # Counter는 음수가 될 수 없으므로, 음수와 0을 제한다 (0은 왜?) => 어쨌든, 새로운 객체를 생성함
# Out:
# Counter({'a': 5, 'b': 2, 'c': 1})

# %% [markdown]
# ## 13.3 벡터를 더하기 위해 + 오버로딩하기

# %%
from Vector.Vector_v6 import Vector

v1 = Vector([3,4,5])
v2 = Vector([6,7,8])

v1 + v2
# Out:
# Vector([9.0, 11.0, 13.0])

# %%
v1 + v2 == Vector([3+6, 4+7, 5+8])
# Out:
# True

# %%
v1 = Vector([3,4,5,6])
v3 = Vector([1,2])
v1 + v3
# Out:
# Vector([4.0, 6.0, 5.0, 6.0])

# %% [markdown]
# ```python
#     pairs = itertools.zip_longest(self, other, fillvalue=0.0)
#     return Vector(a + b for a, b in pairs)
# ```
# - pairs는 self에서 a를, other에서 b를 가져와 (a, b)튜플을 생성하는 제너레이터다. self와 other의 길이가 다른 경우에는 짧은 쪽 반복형의 빠진 값을 fillvalue로 채운다.
# - pairs 양쪽 항목의 합을 생성하는 제너레이터 표현식을 이용해서 새로운 Vector 객체를 생성한다.

# %%
v1 = Vector([3,4,5])
v1 + (10, 20, 30)
# Out:
# Vector([13.0, 24.0, 35.0])

# %%
v1 = Vector([3,4,5])
(10, 20, 30) + v1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/yesinkim/Bailando/Fluent-Python/Yesin/Ch13.Operator Overloading: Doing It Right.ipynb Cell 13 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/yesinkim/Bailando/Fluent-Python/Yesin/Ch13.Operator%20Overloading%3A%20Doing%20It%20Right.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> v1 = Vector([3,4,5])
# ----> <a href='vscode-notebook-cell:/Users/yesinkim/Bailando/Fluent-Python/Yesin/Ch13.Operator%20Overloading%3A%20Doing%20It%20Right.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> (10, 20, 30) + v1
#
# TypeError: can only concatenate tuple (not "Vector") to tuple

# %%
# __radd__를 구현해주면 됨 
def __radd__(self, other):
    return self + other

# %% [markdown]
# ## 13.4 벡터를 스칼라와 곱하기 위해 * 오버로딩하기

# %%
v1 = Vector([1,2,3])
v1 * 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/yesinkim/Bailando/Fluent-Python/Yesin/Ch13.Operator Overloading: Doing It Right.ipynb Cell 16 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/yesinkim/Bailando/Fluent-Python/Yesin/Ch13.Operator%20Overloading%3A%20Doing%20It%20Right.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> v1 = Vector([1,2,3])
# ----> <a href='vscode-notebook-cell:/Users/yesinkim/Bailando/Fluent-Python/Yesin/Ch13.Operator%20Overloading%3A%20Doing%20It%20Right.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> v1 * 10
#
# TypeError: unsupported operand type(s) for *: 'Vector' and 'int'

# %%
from Vector.Vector_v7 import Vector

# %%
v1 = Vector([1,2,3])
v1 * 10
# Out:
# Vector([10.0, 20.0, 30.0])

# %%
11 * v1
# Out:
# Vector([11.0, 22.0, 33.0])

# %%
v1 * True
# Out:
# Vector([1.0, 2.0, 3.0])

# %%
from fractions import Fraction
v1 * Fraction(1, 3)
# Out:
# Vector([0.3333333333333333, 0.6666666666666666, 1.0])

# %% [markdown]
# ## 13.5 향상된 비교 연산자
# 파이썬 인터프리터가 `==`, `!=`, `>`, `<`, `>=`, `<=` 비교 연산자를 다루는 방법은 앞에서 설명한 방법과 비슷하지만(먼저 정방향 메서드를 실행하고, NotImplemented가 반환되면 역순 메서드를 실행한다.)

# %%
def __eq__(self, other):
    return (len(self) == len(other) and
            all(a == b for a, b in zip(self, other)))

# %%
va = Vector([1, 2, 3])
vb = Vector(range(1, 4))
va == vb
# Out:
# True

# %%
t3 = (1, 2, 3)
va == t3
# Out:
# True

# %%
from Vector.Vector_v8 import Vector
va = Vector([1, 2, 3])
va == t3
# Out:
# False

# %% [markdown]
# ## 13.6 복합 할당 연산자
# 우리가 구현한 Vector는 이미 +=과 *= 복합 할당 연산자를 지원하고 있다.

# %%
v1 = Vector([1, 2, 3])
v1_alias = v1
print(id(v1))
v1 += Vector([4, 5, 6])
print(v1)
print(id(v1))
# Out:
# 4380448080
# (5.0, 7.0, 9.0)
# 4380448800

# %%
print(v1_alias)
v1 *= 11
print(v1)
print(id(v1))
# Out:
# (1.0, 2.0, 3.0)
# (55.0, 77.0, 99.0)
# 4380447504

# %%
from bingoaddable import AddableBingoCage

vowels = 'AEIOU'
globe = AddableBingoCage(vowels)
globe.inspect()
# Out:
# ('A', 'E', 'I', 'O', 'U')

# %%
globe.pick() in vowels
# Out:
# True

# %%
len(globe.inspect())
# Out:
# 4

# %%
globe2 = AddableBingoCage('XYZ')
globe3 = globe + globe2
len(globe3.inspect())
# Out:
# 7

# %%
globe3.inspect()
# Out:
# ('A', 'E', 'O', 'U', 'X', 'Y', 'Z')

# %%
void = globe + [10, 20]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/yesinkim/Bailando/Fluent-Python/Yesin/Ch13. Operator Overloading.ipynb Cell 34 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/yesinkim/Bailando/Fluent-Python/Yesin/Ch13.%20Operator%20Overloading.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> void = globe + [10, 20]
#
# TypeError: unsupported operand type(s) for +: 'AddableBingoCage' and 'list'

# %%
globe += 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Bailando/Fluent-Python/Yesin/bingoaddable.py:19, in AddableBingoCage.__iadd__(self, other)
#      18 try:    # <5> Tombola가 아닐 때는 other의 반복자를 가져온다.
# ---> 19     other_iterable = iter(other)
#      20 except TypeError:   # <6> 실패하면 메세지와 함께 예외를 발생시킨다. 가능하면 에러 메시지에 사용자가 문제를 해결할 방밥을 명확히 알려주는 것이 좋다.
#
# TypeError: 'int' object is not iterable
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /Users/yesinkim/Bailando/Fluent-Python/Yesin/Ch13. Operator Overloading.ipynb Cell 36 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/yesinkim/Bailando/Fluent-Python/Yesin/Ch13.%20Operator%20Overloading.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> globe += 1
#
# File ~/Bailando/Fluent-Python/Yesin/bingoaddable.py:23, in AddableBingoCage.__iadd__(self, other)
#      21         self_cls = type(self).__name__
#      22         msg = 'right operand in += must be {!r} or and iterable'
# ---> 23         raise TypeError(msg.format(self_cls))
#      24 self.load(other_iterable)   # <7> 이제 로드해줄 수 있다.
#      25 return self
#
# TypeError: right operand in += must be 'AddableBingoCage' or and iterable
